# %%
import pandas as pd

# %%
# Reading csv data 

df= pd.read_csv('RELI.csv')

# %%
df
# Out:
#     symbol                       date     close      high      low     open  \
# 0     RELI  2016-02-02 00:00:00+00:00  0.600000  0.600000  0.60000  0.60000
# 1     RELI  2016-04-18 00:00:00+00:00  0.050000  0.050000  0.05000  0.05000
# 2     RELI  2016-04-19 00:00:00+00:00  0.620000  0.620000  0.62000  0.62000
# 3     RELI  2016-05-17 00:00:00+00:00  0.620000  0.620000  0.62000  0.62000
# 4     RELI  2016-06-17 00:00:00+00:00  0.110000  0.110000  0.11000  0.11000
# ..     ...                        ...       ...       ...      ...      ...
# 819   RELI  2020-10-02 00:00:00+00:00  0.124900  0.139000  0.11500  0.13900
# 820   RELI  2020-10-05 00:00:00+00:00  0.134500  0.139000  0.11180  0.11180
# 821   RELI  2020-10-06 00:00:00+00:00  0.134625  0.134625  0.12100  0.12490
# 822   RELI  2020-10-07 00:00:00+00:00  0.122500  0.128000  0.11505  0.12800
# 823   RELI  2020-10-08 00:00:00+00:00  0.136100  0.139000  0.12160  0.12665
#
# ...

# %%
df.head()
# Out:
#   symbol                       date  close  high   low  open  volume  \
# 0   RELI  2016-02-02 00:00:00+00:00   0.60  0.60  0.60  0.60     433
# 1   RELI  2016-04-18 00:00:00+00:00   0.05  0.05  0.05  0.05     200
# 2   RELI  2016-04-19 00:00:00+00:00   0.62  0.62  0.62  0.62     200
# 3   RELI  2016-05-17 00:00:00+00:00   0.62  0.62  0.62  0.62      10
# 4   RELI  2016-06-17 00:00:00+00:00   0.11  0.11  0.11  0.11    3000
#
#    adjClose  adjHigh  adjLow  adjOpen  adjVolume  divCash  splitFactor
# 0      0.60     0.60    0.60     0.60        433      0.0          1.0
# 1      0.05     0.05    0.05     0.05        200      0.0          1.0
# 2      0.62     0.62    0.62     0.62        200      0.0          1.0
# 3      0.62     0.62    0.62     0.62         10      0.0          1.0
# 4      0.11     0.11    0.11     0.11       3000      0.0          1.0

# %%
df.tail()
# Out:
#     symbol                       date     close      high      low     open  \
# 819   RELI  2020-10-02 00:00:00+00:00  0.124900  0.139000  0.11500  0.13900
# 820   RELI  2020-10-05 00:00:00+00:00  0.134500  0.139000  0.11180  0.11180
# 821   RELI  2020-10-06 00:00:00+00:00  0.134625  0.134625  0.12100  0.12490
# 822   RELI  2020-10-07 00:00:00+00:00  0.122500  0.128000  0.11505  0.12800
# 823   RELI  2020-10-08 00:00:00+00:00  0.136100  0.139000  0.12160  0.12665
#
#      volume  adjClose   adjHigh   adjLow  adjOpen  adjVolume  divCash  \
# 819  122600  0.124900  0.139000  0.11500  0.13900     122600      0.0
# 820   52982  0.134500  0.139000  0.11180  0.11180      52982      0.0
# 821   51278  0.134625  0.134625  0.12100  0.12490      51278      0.0
# 822   98405  0.122500  0.128000  0.11505  0.12800      98405      0.0
# 823  122884  0.136100  0.139000  0.12160  0.12665     122884      0.0
#
#      splitFactor
# 819          1.0
# 820          1.0
# 821          1.0
# ...

# %%
df.shape
# Out:
# (824, 14)

# %% [markdown]
# Dataframe contains 824 data points and 14 features

# %% [markdown]
# Problem statement : Regression problem statement
#
# We need to predict the stock price based on previous data

# %% [markdown]
# We have data from 2016 to 2020

# %%
New_df=df['low']

# %%
New_df
# Out:
# 0      0.60000
# 1      0.05000
# 2      0.62000
# 3      0.62000
# 4      0.11000
#         ...
# 819    0.11500
# 820    0.11180
# 821    0.12100
# 822    0.11505
# 823    0.12160
# Name: low, Length: 824, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.plot(New_df)

# %%
import numpy as np

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(New_df).reshape(-1,1))

# %%
df1
# Out:
# array([[6.81057068e-01],
#        [5.45620230e-02],
#        [7.03838706e-01],
#        [7.03838706e-01],
#        [1.22906937e-01],
#        [5.67148878e-01],
#        [5.67148878e-01],
#        [5.67148878e-01],
#        [5.67148878e-01],
#        [5.19307438e-01],
#        [6.12712154e-01],
#        [5.10194783e-01],
#        [6.24102973e-01],
#        [5.10194783e-01],
#        [5.10194783e-01],
#        [5.10194783e-01],
#        [5.67148878e-01],
#        [5.32976421e-01],
#        [5.55758059e-01],
#        [5.55758059e-01],
#        [5.14751111e-01],
#        [5.10194783e-01],
#        [5.10194783e-01],
#        [5.10194783e-01],
#        [5.10194783e-01],
#        [4.76022326e-01],
#        [5.10194783e-01],
#        [5.67148878e-01],
#        [3.39332498e-01],
#        [4.53240688e-01],
#        [3.96286593e-01],
#        [4.53240688e-01],
#        [4.00842921e-01],
#        [2.82378403e-01],
#        [4.19068231e-01],
#        [2.82378403e-01],
#        [2.82378403e-01],
# ...

# %%
len(df1)
# Out:
# 824

# %%
##splitting dataset into train and test split
training_size=int(len(df1)*0.65)
test_size=len(df1)-training_size

# %%
training_size
# Out:
# 535

# %%
test_size
# Out:
# 289

# %%
train_data=df1[0:training_size,:]

# %%
test_data=df1[training_size:len(data_set),:1]

# %%
len(train_data),len(test_data)
# Out:
# (535, 289)

# %%
test_data
# Out:
# array([[0.15764893],
#        [0.1683563 ],
#        [0.1753047 ],
#        [0.16858412],
#        [0.16858412],
#        [0.18555644],
#        [0.17792459],
#        [0.17416562],
#        [0.16847021],
#        [0.18555644],
#        [0.18065839],
#        [0.18806242],
#        [0.18806242],
#        [0.19079622],
#        [0.19239093],
#        [0.19387174],
#        [0.1925618 ],
#        [0.20264267],
#        [0.20689031],
#        [0.2085659 ],
#        [0.21403349],
#        [0.20264267],
#        [0.20412348],
#        [0.20571819],
#        [0.20264267],
#        [0.19409956],
#        [0.19683335],
#        [0.20833808],
#        [0.19580818],
#        [0.19387174],
#        [0.20264267],
#        [0.19700421],
#        [0.21409044],
#        [0.21016289],
#        [0.22542431],
#        [0.21528648],
#        [0.21403349],
#        [0.21118578],
#        [0.21517257],
#        [0.23917872],
#        [0.24251054],
#        [0.2444185 ],
#        [0.23681513],
# ...

# %%
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]   
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# %%
time_step = 150
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
X_train
# Out:
# array([[6.81057068e-01, 5.45620230e-02, 7.03838706e-01, ...,
#         9.68219615e-04, 0.00000000e+00, 0.00000000e+00],
#        [5.45620230e-02, 7.03838706e-01, 7.03838706e-01, ...,
#         0.00000000e+00, 0.00000000e+00, 4.55632760e-04],
#        [7.03838706e-01, 7.03838706e-01, 1.22906937e-01, ...,
#         0.00000000e+00, 4.55632760e-04, 0.00000000e+00],
#        ...,
#        [1.74165623e-01, 1.74165623e-01, 1.81000114e-01, ...,
#         1.45688575e-01, 1.51019478e-01, 1.56054220e-01],
#        [1.74165623e-01, 1.81000114e-01, 1.90967081e-01, ...,
#         1.51019478e-01, 1.56054220e-01, 1.46827657e-01],
#        [1.81000114e-01, 1.90967081e-01, 2.02642670e-01, ...,
#         1.56054220e-01, 1.46827657e-01, 1.53092607e-01]])

# %%
y_train[1]
# Out:
# 0.0

# %%
X_train.shape[1]
# Out:
# 150

# %%
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
import tensorflow

# %%
### Create the Stacked LSTM model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(150,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_3 (LSTM)                (None, 150, 50)           10400
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 150, 50)           20200
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 51
# ...
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 6/6 [==============================] - 1s 222ms/step - loss: 0.0065 - val_loss: 0.0027
# Epoch 2/100
# 6/6 [==============================] - 1s 116ms/step - loss: 0.0025 - val_loss: 0.0063
# Epoch 3/100
# 6/6 [==============================] - 1s 111ms/step - loss: 0.0011 - val_loss: 0.0098
# Epoch 4/100
# 6/6 [==============================] - 1s 113ms/step - loss: 8.6340e-04 - val_loss: 0.0021
# Epoch 5/100
# 6/6 [==============================] - 1s 117ms/step - loss: 6.5543e-04 - val_loss: 0.0026
# Epoch 6/100
# 6/6 [==============================] - 1s 111ms/step - loss: 6.6513e-04 - val_loss: 0.0016
# Epoch 7/100
# 6/6 [==============================] - 1s 116ms/step - loss: 6.3436e-04 - val_loss: 0.0021
# Epoch 8/100
# 6/6 [==============================] - 1s 111ms/step - loss: 6.0815e-04 - val_loss: 0.0018
# Epoch 9/100
# 6/6 [==============================] - 1s 117ms/step - loss: 5.7135e-04 - val_loss: 0.0018
# Epoch 10/100
# ...

# %%
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)

# %%
train_predict
# Out:
# array([[0.00298228],
#        [0.0028331 ],
#        [0.00268158],
#        [0.00254733],
#        [0.00243968],
#        [0.00235768],
#        [0.00230927],
#        [0.00232335],
#        [0.00236846],
#        [0.00243012],
#        [0.00247023],
#        [0.00246945],
#        [0.00243884],
#        [0.00240749],
#        [0.00238736],
#        [0.00240492],
#        [0.00247333],
#        [0.00256536],
#        [0.00270838],
#        [0.00289083],
#        [0.00316097],
#        [0.00351435],
#        [0.00394814],
#        [0.00448881],
#        [0.00491626],
#        [0.00525308],
#        [0.00557698],
#        [0.00583605],
#        [0.00601396],
#        [0.00607605],
#        [0.00598891],
#        [0.00587557],
#        [0.00579621],
#        [0.005771  ],
#        [0.0057406 ],
#        [0.00564899],
#        [0.005565  ],
#        [0.00555172],
#        [0.00560871],
#        [0.00563515],
#        [0.00559454],
#        [0.00555584],
#        [0.0054858 ],
# ...

# %%
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_train,train_predict))
# Out:
# 0.020525726039797736

# %%
math.sqrt(mean_squared_error(ytest,test_predict))
# Out:
# 0.09438663673123611

# %%
len(test_data)
# Out:
# 289

# %%
x_input=test_data[189:].reshape(1,-1)
x_input.shape
# Out:
# (1, 100)

# %%
temp_input=list(x_input)
temp_input=temp_input[0].tolist()

# %%
temp_input
# Out:
# [0.3336370885066636,
#  0.35357102175646427,
#  0.3252078824467479,
#  0.32805558719671946,
#  0.32794167900672055,
#  0.34787561225652125,
#  0.37008770930629914,
#  0.33933249800660664,
#  0.28249231119717505,
#  0.28670691422713296,
#  0.2823784030071762,
#  0.2770247180772297,
#  0.2425105365075749,
#  0.20845198769791548,
#  0.21403348900785968,
#  0.2254243080077458,
#  0.21403348900785968,
#  0.2100865702243991,
#  0.21403348900785968,
#  0.22553821619774464,
#  0.21403348900785968,
#  0.20321221095796788,
#  0.22462695067775376,
#  0.2425105365075749,
#  0.25959676500740403,
#  0.2544708964574553,
#  0.2265633899077344,
#  0.21289440710787105,
#  0.14568857500854313,
#  0.18925845768310745,
#  0.17986103200820142,
#  0.18555644150814446,
#  0.1912518510080875,
#  0.20856589588791435,
#  0.1914796673880852,
#  0.21403348900785968,
#  0.20378175190796222,
#  0.20378175190796222,
#  0.1912518510080875,
#  0.20492083380795081,
#  0.20492083380795081,
#  0.2060599157079394,
# ...

# %%
lst_output=[]
n_steps=100
i=0
while(i<30):
    
    if(len(temp_input)>100):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+1
    

print(lst_output)
# Out:
# [0.1431861]
# 101
# 1 day input [0.35357102 0.32520788 0.32805559 0.32794168 0.34787561 0.37008771
#  0.3393325  0.28249231 0.28670691 0.2823784  0.27702472 0.24251054
#  0.20845199 0.21403349 0.22542431 0.21403349 0.21008657 0.21403349
#  0.22553822 0.21403349 0.20321221 0.22462695 0.24251054 0.25959677
#  0.2544709  0.22656339 0.21289441 0.14568858 0.18925846 0.17986103
#  0.18555644 0.19125185 0.2085659  0.19147967 0.21403349 0.20378175
#  0.20378175 0.19125185 0.20492083 0.20492083 0.20605992 0.20845199
#  0.20833808 0.19694726 0.19125185 0.16847021 0.15138398 0.16847021
#  0.17074838 0.16607814 0.14022098 0.14568858 0.14284087 0.14113225
#  0.14568858 0.15337738 0.16049664 0.16960929 0.16847021 0.17416562
#  0.14289782 0.10365645 0.13429776 0.12313475 0.13201959 0.12575464
#  0.11424991 0.11561681 0.1126552  0.11721153 0.11721153 0.11835061
#  0.12290694 0.12490033 0.12404602 0.13145005 0.14682766 0.16391389
#  0.17416562 0.1821392  0.17248548 0.11721153 0.15480123 0.16733113
# ...

# %%
day_new=np.arange(1,101)
day_pred=np.arange(101,131)

# %%
len(df1)
# Out:
# 824

# %%
plt.plot(day_new,scaler.inverse_transform(df1[724:]))
plt.plot(day_pred,scaler.inverse_transform(lst_output))

# %%
df3=df1.tolist()
df3.extend(lst_output)
plt.plot(df3[700:])

# %%
len(df3)
# Out:
# 854

# %%
df3=scaler.inverse_transform(df3).tolist()

# %%
plt.plot(df3)
